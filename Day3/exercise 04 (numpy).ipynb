# %%
import numpy as np
dataset = np.genfromtxt("data.csv", delimiter=";")
dataset
# Out:
# array([[ 97.,  45.,  12., ..., 100.,  61.,  66.],
#        [ 33.,  57.,  77., ...,  24.,  52.,  57.],
#        [ 16.,  34.,  82., ...,  80.,  35.,   9.],
#        ...,
#        [ 52.,  38.,  40., ...,  33.,   8.,  17.],
#        [ 69.,  98.,  82., ...,  53.,  66.,  17.],
#        [ 93.,  76.,  67., ...,  68.,  89.,  81.]], shape=(47, 29))

# %%
dataset.sum()
# Out:
# np.float64(68734.0)

# %%
column_index = 0
column_data = dataset[:, column_index]
column_data
# Out:
# array([97., 33., 16., 23., 46., 38., 27., 16.,  3., 22., 31., 54., 16.,
#        31., 20., 30., 86., 76., 17.,  8., 41., 48., 21., 14.,  4., 48.,
#        38., 93., 37., 34., 68., 48., 44., 12., 66., 65., 21., 64., 18.,
#        97., 41., 20.,  6.,  9., 52., 69., 93.])
