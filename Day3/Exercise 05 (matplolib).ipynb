# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,3,-50,100,11]

plt.plot(x,y)
plt.title("Sample Plot")
plt.xlabel("Days")
plt.ylabel("Rain mm")
plt.show()

# %% [markdown]
# # Bar Chart

# %%
catagories = ["Company A", "Company B", "Company C", "Company D"]

values = [20, 50,-10, 40]

colors = ["green", "blue", "red", "orange"]

plt.bar(catagories, values,color=colors)
plt.title("Bar Chart")
plt.xlabel("Northwest Companies")
plt.ylabel("Revenutes")
plt.xticks(rotation=45)

plt.show()

# %%
np.arange(len(categories))
# Out:
# array([0, 1, 2, 3])

# %%
from mpl_toolkits.mplot3d import Axes3D

catagories = ["Company A", "Company B", "Company C", "Company D"]

values = [20, 50, 10, 40]

colors = ["green", "blue", "red", "orange"]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.arange(len(categories))

ax.bar(x, values,  color=colors)
plt.xticks(x)

plt.bar(catagories, values,color=colors)


# plt.title("Bar Chart")
# plt.xlabel("Northwest Companies")
# plt.ylabel("Revenutes")
# plt.xticks(rotation=45)

plt.show()
