# %%
if 10 > 50:
    print("Ten is bigger than five")
    
print("Today is sunny")
# Out:
# Today is sunny

# %%
if 10 > 50:
    print("Ten is bigger than five")
else:
    print("it's lower")
    
print("Today is sunny")
# Out:
# it's lower
# Today is sunny

# %%
def addition(a,b):
    """
    This function receives two values that are summed together
    """
    result = a+b # a is added to b and associated with "result"
    return result # we return the "result" variable

# %%
addition(10,20)
# Out:
# 30

# %%
addition ("Mike", "Elisa")
# Out:
# 'MikeElisa'

# %%
age = 30

# %%
Age = 20

# %%
age
# Out:
# 30

# %%
Age
# Out:
# 20

# %%
building1_name = "Church" # snake syntax
building1Name = "Church" # snake syntax

biulding1_height = 100

building2_name = "Stadium"
biulding2_height = 200

building3_name = "Igloo"
biulding3_height = 1

# %%
age = 40.5

# %%
student_name = "Maria"
print(student_name)
print(student_name+student_name)
# Out:
# Maria
# MariaMaria

# %%
type(age)
# Out:
# float

# %%
dangerous = True

# %%
type(dangerous)
# Out:
# bool

# %%
type(3>5)
# Out:
# bool

# %%
d = str(dangerous)

# %%
type(d)
# Out:
# str

# %%
d
# Out:
# 'True'

# %%
s = "20a"

# %%
int(s)+int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 int(s)+int(s)
#
# ValueError: invalid literal for int() with base 10: '20a'

# %%
a = 10
b = "Julie"
c = True
d = 3.5

# %%
type(d)
# Out:
# float

# %%
type(float(a))
# Out:
# float
